# %%
#import required Python libraries 
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate 
import seaborn as sns

# %%
#initialize linear space
x = np.linspace(0, 300, 25, endpoint=True)
print(x)
#set logistic growth example with added randomness
y = 30*np.random.randn(25)+(1000/(1+np.exp(-0.02*(x-0.1))))
print(y)
# Out:
# [  0.   12.5  25.   37.5  50.   62.5  75.   87.5 100.  112.5 125.  137.5
#  150.  162.5 175.  187.5 200.  212.5 225.  237.5 250.  262.5 275.  287.5
#  300. ]
# [ 476.06456264  569.26167025  640.62077556  698.25455629  757.25056061
#   826.06278213  788.83678533  855.51677906  907.76244826  927.56743346
#   977.25894471  936.72606084  865.18500607  942.57606114  943.77681387
#   941.29813874  968.79796611  940.59901402  961.01294879  968.98376756
#   967.42670012  978.93796558 1019.64890667  983.47726332 1016.62494003]

# %%
#plot raw data
plt.plot(x,y,'o')
sns.lineplot(x,y)
plt.show
# Out:
# /Users/gabriellesmith/opt/anaconda3/envs/eds-217/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from scipy.interpolate import UnivariateSpline
#set one-dimensional smoothing spline as a function of x and y 
spl = UnivariateSpline(x,y)
#initialize sample space with more data points than observed
xs = np.linspace(0,300,1000)
#plot smoothed 
# sample data 
plt.plot(xs, spl(xs),'g',lw=2)
plt.show()

# %%
fig = plt.figure()
#plot raw data
plt.plot(x,y,'o')
sns.lineplot(x,y)
#plot smoothed data 
plt.plot(xs,spl(xs),'g',lw=2)
# Out:
# /Users/gabriellesmith/opt/anaconda3/envs/eds-217/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
